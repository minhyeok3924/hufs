em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','h100****', 'zVcsT9bizzIIAX2dzeQPUMxA4M6j/APTsPvQ7AI4pT4=', '이순신, 그는 신이다. ', '8979543', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8979543">12875</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8979543">2260</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용
review_text = lis[0].find('p').find('span').getText()
review_text
# Out:
# '\n\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t오늘 명량 시사회로 방금 보고 왔음. 단연코 올해의 수작임. 밑에 평론가들 캐릭터 어쩌고 하는데 류승룡 캐릭터 더 살리면 일본장수 미화한다며 입털게 분명. 평론가들 하는 짓이라곤 남이 차린 밥상 맛있네 맛없네 까대며...\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용 -- 부호 빼고 깨끗하게!
review_text = lis[0].find('p').find('span').getText().strip()
review_text
# Out:
# '오늘 명량 시사회로 방금 보고 왔음. 단연코 올해의 수작임. 밑에 평론가들 캐릭터 어쩌고 하는데 류승룡 캐릭터 더 살리면 일본장수 미화한다며 입털게 분명. 평론가들 하는 짓이라곤 남이 차린 밥상 맛있네 맛없네 까대며...'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[1]/em

## 평점 점수
score = lis[0].find('em').getText()
score
# Out:
# '10'

# %%
#/html/body/div/div/div[5]/ul/li[1]/div[3]/a[1]/strong --> 좋아요. 
# /html/body/div/div/div[5]/ul/li[1]/div[3]/a[2]/strong --> 싫어요

## 좋아요/싫어요 점수
like = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[0].getText()
dislike = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[1].getText()
like, dislike
# Out:
# ('16767', '4980')

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[1]/a/span

## 덧글 작성자 닉네임
nickname = lis[0].findAll('a')[0].find('span').getText()
nickname
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-e0e098a566a6> in <module>()
#       2
#       3 ## 덧글 작성자 닉네임
# ----> 4 nickname = lis[0].findAll('a')[0].find('span').getText()
#       5 nickname
#
# AttributeError: 'NoneType' object has no attribute 'getText'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[2]

from datetime import datetime
created_at = datetime.strptime(lis[0].find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
created_at
# Out:
# datetime.datetime(2014, 1, 22, 0, 33)

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 93756
total_count = 100  ## 전체 크기=36524

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['chocobar(choc****)',
#   '오늘 명량 시사회로 방금 보고 왔음. 단연코 올해의 수작임. 밑에 평론가들 캐릭터 어쩌고 하는데 류승룡 캐릭터 더 살리면 일본장수 미화한다며 입털게 분명. 평론가들 하는 짓이라곤 남이 차린 밥상 맛있네 맛없네 까대며...',
#   '10',
#   '16767',
#   '4980',
#   datetime.datetime(2014, 7, 30, 1, 31),
#   0],
#  ['누구세요(h100****)',
#   '이순신, 그는 신이다.',
#   '10',
#   '12875',
#   '2260',
#   datetime.datetime(2014, 7, 30, 0, 2),
#   0],
#  ['드리머(hama****)',
#   '군도보다 훨씬 잼있음..극장가서 꼭 보세요',
#   '10',
#   '9608',
#   '2557',
#   datetime.datetime(2014, 7, 30, 0, 5),
#   0],
#  ['지영(yjy3****)',
#   '29일 시사회로 봤어요냉정하게이건 꼭 봐야해..굿',
#   '10',
#   '8083',
#   '2011',
#   datetime.datetime(2014, 7, 30, 0, 20),
#   0],
#  ['csh0****',
#   '정말 재미있네요 잘보고 왔습니다 시사회',
#   '10',
#   '6849',
#   '1873',
#   datetime.datetime(2014, 7, 30, 0, 0),
#   0],
#  ['디스(csj3****)',
#   '오늘 아침에 조조로 보고왔습니다. 8월4일에 해군에 입대하는데. 그전에 보기 잘한 영화같습니다. 평소에 영화 많이 좋아하고 자주보는 편인데. 무지 재미있게 봤습니다. 나라 잘지키고 오겠습니다 필승',
#   '10',
#   '5793',
#   '831',
#   datetime.datetime(2014, 7, 30, 17, 23),
#   '관람객'],
#  ['akst****',
#   '극찬할 수는 없지만 이 정도면 내용, 영상, 연출 전부 꽤나 뛰어난 작품이지 않은가? 평론가들의 평점 6점은 도대체 어떻게 해서 나온 점수인지... 블랙펄 같은 배가 나오고 판옥선이 거북선으로 트랜스포머하는 장면이 ...',
#   '9',
#   '5157',
#   '1391',
#   datetime.datetime(2014, 7, 30, 12, 57),
#   '관람객'],
#  ['몰라(aowz****)',
#   '국가에 버림을 받아도 의리로 지키려는 충신. 피를 흘리면서 싸우는 군인들의 투지. 두려움을 넘어선 백성들의 의지. 소중한 가족들을 잃은 민족의 한...  슬픈 명작이었습니다....',
#   '10',
#   '3315',
#   '493',
#   datetime.datetime(2014, 7, 30, 0, 13),
#   0],
#  ['아라리요(zzon****)',
#   '보는 내내 가슴찡하고 울컥하는 진짜 최고의 영화ㅠㅠ한 순간도 놓칠 수 없는 해전씬이 특히 압권!!',
#   '10',
#   '3052',
#   '562',
#   datetime.datetime(2014, 7, 30, 10, 28),
#   '관람객'],
#  ['영웅본색(khj1****)',
#   '작금의 이시점에 국가가 혼란하고 위태할수록국가를 직간접으로 책임지고 있는 리더에게 무엇이 필요한지 리더의 마음이 한치의 흔들림없이 무엇을 향하고 있어야 하는지를 세치의 혀가 아닌 온몸으로 400년전 구국의영웅이 20...',
#   '10',
#   '2799',
#   '467',
#   datetime.datetime(2014, 7, 30, 13, 6),
#   '관람객'],
#  ['갠지쭈(lkj4****)',
#   '평론가 진짜 싫엌ㅋㅋ ㅠㅠㅠ난 진짜ㅠㅠ 감동적이었는데',
#   '10',
#   '2690',
#   '601',
#   datetime.datetime(2014, 7, 30, 1, 20),
#   0],
#  ['ryus****',
#   '"내가 제일로 두려워하는 사람은 이순신이며, 가장 미운사람도 가장 좋아하는 사람도 이순신이며, 가장 흠모하고 숭상하는 사람도 이순신이며, 가장 죽이고 싶은 사람 역시 이순신이며, 가장 차를 함께 하고 싶은 이...',
#   '10',
#   '2338',
#   '279',
#   datetime.datetime(2014, 7, 30, 3, 7),
#   0],
#  ['제이별(cheo****)',
#   '감동을 넘어서 엄숙하기까지 했던, 말 그대로 명량 그 자체였다. 영화에 정말 공을 많이 들인 게 느껴졌고 특히 최민식님의 이순신 장군은 대사가 얼마 없는데도 그만이 주는 압도감에 스크린을 뛰어 넘어 가까이에서 살아 ...',
#   '10',
#   '2267',
#   '334',
#   datetime.datetime(2014, 7, 30, 0, 42),
#   0],
#  ['델타포스(capt****)',
#   '이순신을 5만원짜리에다가 ,,, ..넣라',
#   '10',
#   '1564',
#   '223',
#   datetime.datetime(2014, 7, 30, 2, 54),
#   0],
#  ['real****',
#   '전쟁씬에서 입벌리고봄',
#   '8',
#   '1649',
#   '309',
#   datetime.datetime(2014, 7, 30, 11, 13),
#   '관람객'],
#  ['천재외계인(bunn****)',
#   '우리나라에서도이런해상전투씬이 나오다니 압권이다 더불어 이순신장군님의 위대함까지 다시한번 생각하게하는영화',
#   '10',
#   '1564',
#   '243',
#   datetime.datetime(2014, 7, 30, 10, 24),
#   '관람객'],
#  ['ddddddd(yhy1****)',
#   '평론가놈들 정체가뭐냐 명량이 어떻게 군도보다 평점이낮냐',
#   '10',
#   '1293',
#   '264',
#   datetime.datetime(2014, 7, 30, 9, 48),
#   0],
#  ['kimk****',
#   '안봤으면 후회할 영화! 안볼수 없었더 영화! 모두가 봤으면 하는 영화!',
#   '10',
#   '1241',
#   '262',
#   datetime.datetime(2014, 7, 30, 11, 9),
#   '관람객'],
#  ['화이낫(agai****)',
#   '올해 최고의 수작. 성웅 이순신 그는 위대한 조선의 장수',
#   '10',
#   '1185',
#   '231',
#   datetime.datetime(2014, 7, 30, 11, 10),
#   '관람객'],
#  ['메아리(tjda****)',
#   '장면 하나하나가 소름이고 감동.. ㅜㅜ 이런 영화가 천만이 넘어야함',
#   '10',
#   '1182',
#   '235',
#   datetime.datetime(2014, 7, 30, 12, 1),
#   '관람객'],
#  ['roks****',
#   '내용이 뻔해서 별로라고? 지금 대한민국의 역사를 가지고 장난질을 해야.... 재밌다는 것이냐? 머리가 뭐가 들은거지? 정말 이순신 장군님께 부끄러울 따름이다',
#   '10',
#   '1127',
#   '182',
#   datetime.datetime(2014, 7, 30, 11, 47),
#   0],
#  ['스마일(kimf****)',
#   '영화보는 동안 줄곧 든 생각 한가지. 정말 고생 많았을듯. 잘보고 감동받고 갑니다.',
#   '10',
#   '1026',
#   '191',
#   datetime.datetime(2014, 7, 30, 12, 9),
#   '관람객'],
#  ['예빈이네(lets****)',
#   '관람내나 감동이었습니다.',
#   '10',
#   '947',
#   '203',
#   datetime.datetime(2014, 7, 30, 10, 46),
#   '관람객'],
#  ['yong****',
#   '완전 명작....무조건 봐야됩니다 한국사람이라면',
#   '10',
#   '978',
#   '237',
#   datetime.datetime(2014, 7, 30, 11, 35),
#   '관람객'],
#  ['xell****',
#   '김한민 감독님 미리 천만 축하드립니다 ㅎ완전 대박 ㅎ노량도 만들어 주십쇼',
#   '10',
#   '898',
#   '186',
#   datetime.datetime(2014, 7, 30, 13, 7),
#   '관람객'],
#  ['tjdl****',
#   '진부하게 영웅이 왜놈 다쓸어버리는게 아니고 굉장히 사실적이다다시 한번 위인 이순신을 생각해보는 계기가 됨',
#   '9',
#   '790',
#   '166',
#   datetime.datetime(2014, 7, 30, 15, 5),
#   '관람객'],
#  ['bsl7****',
#   '진짜진짜 재미있음!!',
#   '10',
#   '784',
#   '175',
#   datetime.datetime(2014, 7, 30, 0, 10),
#   0],
#  ['짠분(kit3****)',
#   '내인생의 진정한 영웅  이순신!!',
#   '10',
#   '722',
#   '132',
#   datetime.datetime(2014, 7, 30, 0, 24),
#   0],
#  ['Placebo Effect(cyon****)',
#   '신에게는 아직 12척의 배가 있습니다!!두려움이 용기로 바뀌는 순간  울컥!!!올해본 한국영화중에 제일좋았습니다',
#   '9',
#   '595',
#   '97',
#   datetime.datetime(2014, 7, 30, 1, 12),
#   0],
#  ['kens****',
#   '후속작 기대해봅니다 거북선이 너무 보고싶어요',
#   '10',
#   '576',
#   '114',
#   datetime.datetime(2014, 7, 30, 12, 13),
#   '관람객'],
#  ['나루세(lali****)',
#   '정치인들 좀 봐라...',
#   '10',
#   '463',
#   '63',
#   datetime.datetime(2014, 7, 30, 10, 0),
#   0],
#  ['unme****',
#   '영화로나마 전쟁 중 이순신 장군의 고뇌와 애민정신을 엿볼 수 있었습니다. 나라가 어지럽고 시끄럽지만 선현들의 피와 노력으로 지켜낸 자랑스러운 대한민국임을 다시 한 번 가슴에 새길 수 있는 뜻깊은 시간이었습니다.',
#   '8',
#   '473',
#   '83',
#   datetime.datetime(2014, 7, 30, 0, 6),
#   0],
#  ['나는꽃(cuy0****)',
#   '나는 오늘 성웅 이순신과 인간 이순신을 보았고 전쟁 영화를 보며 울컥 거린건 너무너무 오랜만인거 같다',
#   '9',
#   '479',
#   '89',
#   datetime.datetime(2014, 7, 30, 12, 42),
#   '관람객'],
#  ['최창규(free****)',
#   '재미있습니다. 새삼 이순신 장군님의 위대함을 느낄 수 있었고 다큐가 아닌 영화로써의 재미도 충분했습니다.',
#   '10',
#   '491',
#   '108',
#   datetime.datetime(2014, 7, 30, 0, 4),
#   0],
#  ['jjb5****',
#   '올해 최고의 영화인 것 같습니다.이순신 장군 너무 훌륭하고 위대하시다는걸 이 영화를 통해 다시한번 깨닫게되네요..',
#   '10',
#   '470',
#   '101',
#   datetime.datetime(2014, 7, 30, 11, 37),
#   '관람객'],
#  ['포키투(pork****)',
#   '누가 도대체 지루하다고 하는거야? 초반의 그 두려움이 느껴지지 않던가요? 전쟁씬은 어떻구요...',
#   '10',
#   '463',
#   '102',
#   datetime.datetime(2014, 7, 30, 18, 19),
#   '관람객'],
#  ['슈레더(godl****)',
#   '이순신은 진정한 영웅이지 백년을 더 물고 빨아도 모자르다',
#   '10',
#   '418',
#   '69',
#   datetime.datetime(2014, 7, 30, 15, 42),
#   '관람객'],
#  ['CaffeLatte(lote****)',
#   '조조로 보고왔는데 지루함 없이 재미있게 잘봤습니다~ 연기도 좋았구요!!',
#   '10',
#   '451',
#   '102',
#   datetime.datetime(2014, 7, 30, 10, 57),
#   '관람객'],
#  ['진천군(cola****)',
#   '재미있게 잘 봤습니다. 한산대첩도 기대되네요. 구선~!',
#   '9',
#   '438',
#   '90',
#   datetime.datetime(2014, 7, 30, 11, 41),
#   '관람객'],
#  ['히힛(ltes****)',
#   '냉정하게 재밌습니다. 평론가평점 믿을게 못됨오히려 관람객 평점 구린영화가 평론가 평점은 높더라고요.',
#   '10',
#   '447',
#   '108',
#   datetime.datetime(2014, 7, 30, 17, 18),
#   '관람객'],
#  ['yoyoyo00(juli****)',
#   '최민식이 아니었다면 누가 해냈을까 싶을 정도, 최고다! 소름 돋는 연기력.. b',
#   '10',
#   '390',
#   '67',
#   datetime.datetime(2014, 7, 30, 0, 53),
#   0],
#  ['peppermint(mint****)',
#   '대사 한마디 한마디가 마음에 남네요~이를 어찌하고...',
#   '10',
#   '377',
#   '81',
#   datetime.datetime(2014, 7, 30, 12, 11),
#   '관람객'],
#  ['로그아웃(goki****)',
#   '이순신이 있었기에 후세에 당신의 영화를 볼수 있게 되었습니다.. 감사합니다',
#   '10',
#   '331',
#   '43',
#   datetime.datetime(2014, 7, 30, 1, 0),
#   0],
#  ['Newages(dhks****)',
#   '두번 봐야 할 영화입니다',
#   '10',
#   '388',
#   '100',
#   datetime.datetime(2014, 7, 30, 10, 59),
#   '관람객'],
#  ['쩡절(toy6****)',
#   '최고의영화  후반해상씬 은 압도적 입니다 꼭보시길',
#   '10',
#   '366',
#   '80',
#   datetime.datetime(2014, 7, 30, 11, 25),
#   '관람객'],
#  ['신혜진(sdir****)',
#   '박진감넘치고재미도있지만 대한민국 국민이라면 봐야하는영화다. 마지막에 배안에서 노젓던백성이 나중에후손들이 우리가이랬던걸 알아주겠냐고 말했을때 느꼈다. 우린 알아야만한다. 평론가들은 닥치시길..',
#   '10',
#   '331',
#   '48',
#   datetime.datetime(2014, 7, 30, 15, 19),
#   0],
#  ['행복한야옹(godn****)',
#   '무거운분위기임에도 지겹지않았어요',
#   '10',
#   '352',
#   '77',
#   datetime.datetime(2014, 7, 30, 15, 28),
#   '관람객'],
#  ['멜(gard****)',
#   '근래 잔인한 액션 영화가 많아서 반신반의로 봤는데...눈물이 주룩..ㅜ 어벤져스에 나오는 괴물들과 비교도 안되는 진짜 히어로 이순신 장군님!',
#   '9',
#   '313',
#   '49',
#   datetime.datetime(2014, 7, 30, 15, 50),
#   0],
#  ['글라스김(kyur****)',
#   '그냥 대한민국 국민이면 다 봤으면 좋겠습니다 비록 웃기는 장면 하나없고 때론 지루하지만 가슴이 먹먹해지는 감동이 있네요. 이순신장군님에 대한 생각을 다시 한번 더 가져보는 시간이었네요',
#   '10',
#   '299',
#   '45',
#   datetime.datetime(2014, 7, 30, 15, 45),
#   0],
#  ['맨담(afew****)',
#   '저기 기자, 평론가들...그들에게 영화에 대한 평을 하는 전문가라고 하는 타이틀은 누가 준 건가요? 자격증인가? 긁적...말 장난도 지겹다..침몰하는 캐릭터들?...뭐냐?...일반인 관객들의 평가나 지적들이 훨씬 더...',
#   '10',
#   '340',
#   '88',
#   datetime.datetime(2014, 7, 30, 16, 47),
#   0],
#  ['변액유니(nait****)',
#   '이런 영화는 정말 대한민국모든 국민이 봐야함.도망치는아군들이이해는 되지만이순신은정말 어떻게 싸웠을까거의 기적에 가까움 12척대 330척이 아니라 1척대 330척이라...이건 정말 세계해전역사상 전무후무한 해전임,다시...',
#   '10',
#   '289',
#   '38',
#   datetime.datetime(2014, 7, 30, 16, 48),
#   0],
#  ['dlqu****',
#   '관직에계신분들이라면꼭보아야할영화',
#   '10',
#   '306',
#   '60',
#   datetime.datetime(2014, 7, 30, 12, 26),
#   '관람객'],
#  ['이주현(this****)',
#   '영화의 plot부터 음향효과 배우들의 연기들 정말 감동이었습니다배우 최민식씨의 이순신장군도 정말 멋졌으며 이순신장군이 또 한번 대단하다는것을 새삼 깨닫게된 영화였습니다. 한순간도 긴장감을 놓칠 수 없을만큼 대단한 말...',
#   '10',
#   '307',
#   '69',
#   datetime.datetime(2014, 7, 30, 12, 20),
#   '관람객'],
#  ['불란서(wook****)',
#   '이순신 장군을 10만원 권으로!!!!',
#   '10',
#   '280',
#   '43',
#   datetime.datetime(2014, 7, 30, 17, 38),
#   0],
#  ['아이스쇼(aksa****)',
#   '영화같지만 영화같지않은 영화였습니다... 특히 이순신장군이 전투중에 "백병전이다!!!"라고 한 이후의 조선군과일본군의 처절한 전투장면... 정말 제 기억속에 오래 남을거 같습니다..',
#   '10',
#   '281',
#   '55',
#   datetime.datetime(2014, 7, 30, 17, 2),
#   '관람객'],
#  ['ysj6****',
#   '보는내내 감동이었습니다.이순신 장군의 고내가 너무 많이 느껴져 눈물이 계속나오더라구요~ 최민식의 연기 또한압권이었습니다^^',
#   '10',
#   '280',
#   '55',
#   datetime.datetime(2014, 7, 30, 13, 20),
#   '관람객'],
#  ['qwsd****',
#   '해상씬이 진짜 역대 최고임...',
#   '10',
#   '256',
#   '45',
#   datetime.datetime(2014, 7, 30, 1, 53),
#   0],
#  ['세조(yund****)',
#   '오늘 아침 첫타임으로 명량을 봤거든요?진심 꿀잼 배우들이 연기를 매우 잘하셔가주고 중간중간에 울컥한 장면도 많았고,해전씬은 우리나라 전쟁영화 중 명장면 top3안에 들 것 같습니다.보니까 이거 3부작이라는 설이 있던...',
#   '10',
#   '238',
#   '43',
#   datetime.datetime(2014, 7, 30, 11, 53),
#   0],
#  ['군계일학(tkdg****)',
#   '신에게는 아직 12척의 배가 남아 있사옵니다!',
#   '10',
#   '231',
#   '44',
#   datetime.datetime(2014, 7, 30, 2, 26),
#   0],
#  ['씨에나(sien****)',
#   '나라가 어지러운 이 시기에 꼭봐야할 영화... 역사상 가장 위대하고 진정한 영웅, 이순신 장군님 존경합니다!!! 이런 영웅이 지금 시대에 다시 오시면 정말 좋겟네요...',
#   '10',
#   '221',
#   '40',
#   datetime.datetime(2014, 7, 30, 10, 45),
#   0],
#  ['수지남친(2018****)',
#   '오늘 조조로 보고왔는데 진짜 재밌다. 재밌다는게 정말 볼만 하다는 말이고 최민식으로 안보이고 진짜 이순신으로 보여서 계속 눈물을 흠칫흠칫함..이미 아는 얘기지만 그 얘기를 영화로 보니까 실제 있었던 일이라는게 생생해...',
#   '10',
#   '219',
#   '42',
#   datetime.datetime(2014, 7, 30, 14, 38),
#   0],
#  ['swee****',
#   '감동! 최고!!!평론가들 평점이 이해할 수 없다ㅠㅜ',
#   '10',
#   '227',
#   '54',
#   datetime.datetime(2014, 7, 30, 11, 59),
#   0],
#  ['yang****',
#   '대한민국인이라면 10점을 안줄수없는..진짜.. 우리민족의 민족성을 볼수있는 그런영화였습니다.정말최고였습니다.',
#   '10',
#   '218',
#   '49',
#   datetime.datetime(2014, 7, 30, 11, 4),
#   0],
#  ['tood****',
#   '너무좋습니다 그때 당시 애국자가 한명이라 있어서 우리가 있지 않은가 생각해 봅니다',
#   '10',
#   '212',
#   '46',
#   datetime.datetime(2014, 7, 30, 12, 3),
#   '관람객'],
#  ['하하하하하(chhy****)',
#   '더 말이 필요한가...',
#   '10',
#   '210',
#   '46',
#   datetime.datetime(2014, 7, 30, 0, 49),
#   0],
#  ['구찌(0r7r****)',
#   '언플 고평점 많은 관 ..이순신 장군님은 위대합니다. 허나 이 영화는 위대하지 않습니다. 전쟁씬 나오기까지 지루합니다.실화가 아니였으면 애국심을 일으키지 않았더라면이정도의 인기는 없었을 애국팔이 영화',
#   '1',
#   '295',
#   '133',
#   datetime.datetime(2014, 8, 6, 1, 46),
#   0],
#  ['thro****',
#   '이순신장군님 정말 존경합니다만, 연출, 스토리, 초반에 너무 지루한것은 부정할수 없다.. 다들 10점 넘는 평점을 줘서, 어쩔수없이 1점을 주었으나, 이 영화는 딱 정확하게 한국영화의 현 한계를 보여줌과 동시에 한국...',
#   '1',
#   '314',
#   '155',
#   datetime.datetime(2014, 8, 8, 11, 57),
#   '관람객'],
#  ['돼미양(dami****)',
#   '까는분들..영화나 보고 오세요. . . .최고..ㅠㅠ',
#   '10',
#   '215',
#   '57',
#   datetime.datetime(2014, 7, 30, 15, 37),
#   0],
#  ['하늘빛(suna****)',
#   '저만 재미없게봤나요..연기자들의  연기력이 아깝네요..',
#   '1',
#   '304',
#   '150',
#   datetime.datetime(2014, 8, 8, 23, 22),
#   '관람객'],
#  ['마포갈매기(vkfm****)',
#   "좀...솔직해집시다... 이 좋은 소재...배우로  '이 따위' 연출을 저지른 감독을 제일 먼저 비판하고 싶네요... 턱 없이 높은 평점 매기는 분들... 영화 관람 후 남기는 것인지는 모르겠지만.. ...",
#   '1',
#   '329',
#   '175',
#   datetime.datetime(2014, 8, 3, 11, 36),
#   0],
#  ['으항항(rlaw****)',
#   '이것이 바로 우리나라다.',
#   '10',
#   '189',
#   '36',
#   datetime.datetime(2014, 7, 30, 17, 44),
#   '관람객'],
#  ['아라진(love****)',
#   '허무맹랑한 영화보다 이런게 진정영화다',
#   '10',
#   '191',
#   '38',
#   datetime.datetime(2014, 7, 30, 11, 43),
#   0],
#  ['심도날드(dudg****)',
#   '어떻게 이런 영화가 9점대지??다들 진짜 최면걸리셧나?',
#   '1',
#   '286',
#   '135',
#   datetime.datetime(2014, 8, 3, 12, 16),
#   0],
#  ['쥐스틴(edde****)',
#   '사람들 애국심자극해서 팔아먹으려는 수작.. 알바 풀지말고 정정당당히 해라 그래야 한국영화 발전한다 허접한 감독 다 걸러내라 허접한 영화로 위인 깎아 내리지 말고',
#   '1',
#   '285',
#   '135',
#   datetime.datetime(2014, 8, 3, 12, 35),
#   0],
#  ['kuki****',
#   '지루한전개와 약간의 억지스러운 각색',
#   '1',
#   '287',
#   '137',
#   datetime.datetime(2014, 8, 3, 12, 28),
#   0],
#  ['밍잉캐잉(dlwh****)',
#   '왜놈들 각오하라. 구선이 간다.',
#   '10',
#   '193',
#   '44',
#   datetime.datetime(2014, 7, 30, 15, 36),
#   '관람객'],
#  ['신수영영어학원(ssye****)',
#   '최고예요 전 출정때 너무비참해서 막 울었어요  전다시한번볼예정이예요 음악좋고 일본을 무게감있고  멋있게 표현한것도 위압적이고 음악좋고 최민식전투신 몰입도 좋네요 적군이아니라 아군이불태운거북선은 너무 현실적이라 화가나...',
#   '10',
#   '177',
#   '30',
#   datetime.datetime(2014, 7, 30, 15, 36),
#   0],
#  ['BomNar(wkdb****)',
#   '6.5점정도가 적절한 평점이라고 생각합니다. 정말 기대 이하로 스토리도 부실하고 등장인물 설정도 부실하며 왜선과 판옥선의 전투력 차이도 너무 어처구니없었습니다. 백성들이 응원하는것도 너무 거슬리고.. 액션도 별로였는...',
#   '1',
#   '428',
#   '282',
#   datetime.datetime(2014, 8, 2, 23, 5),
#   '관람객'],
#  ['설매(tgmo****)',
#   '전투 장면 보는 내내 정말 감동적...오랜만에 영화보며 감동에 눈물을...',
#   '10',
#   '195',
#   '52',
#   datetime.datetime(2014, 7, 30, 15, 42),
#   '관람객'],
#  ['gimi****',
#   '충무공 이순신을 소재로 닭살돋는 억지신파에 허접한 CG, 스모키화장만 하면 카리스마인줄아는 악역들에, 잘못된 고증, 평점 9점대에 가까운 영화라는게 우리 영회계 인식 수준인거 같아 쪽팔리고 부끄럽다. 알바생들 동원 ...',
#   '1',
#   '446',
#   '303',
#   datetime.datetime(2014, 8, 3, 3, 55),
#   '관람객'],
#  ['tmxk****',
#   '올해 본 영화중에 처음 울었어요..진짜 뭉클 잊지않겠습니다 지켜주셔서 감사해요..ㅜㅜ',
#   '10',
#   '172',
#   '34',
#   datetime.datetime(2014, 7, 30, 15, 37),
#   0],
#  ['쥬쥬(jrok****)',
#   '집단최면. 모두 진심입니까',
#   '1',
#   '277',
#   '139',
#   datetime.datetime(2014, 8, 3, 12, 11),
#   0],
#  ['lsb9****',
#   '살면서 리뷰 처음달아봅니다',
#   '1',
#   '312',
#   '177',
#   datetime.datetime(2014, 8, 4, 23, 14),
#   '관람객'],
#  ['이네짱(chin****)',
#   'ㅠ 전 왜이렇게 재미가 없었을까요ㅠ',
#   '1',
#   '271',
#   '137',
#   datetime.datetime(2014, 8, 3, 13, 22),
#   0],
#  ['익명(kims****)',
#   '재미있게 봤어요 . 명랑대첩의 그 순간을  진실되게 재현하신 배우 여러분의 열연에 감명받고 갑니다.',
#   '9',
#   '172',
#   '40',
#   datetime.datetime(2014, 7, 30, 13, 13),
#   '관람객'],
#  ['rhkr****',
#   '진심재밌음 조상님들께 감사함을 느끼게해주는영화ㅎㅎㅎ이순신장군에 위대함을다시한번알게해주는영화',
#   '10',
#   '153',
#   '24',
#   datetime.datetime(2014, 7, 30, 15, 37),
#   0],
#  ['피터팬(zptc****)',
#   '보는내내 가슴이벅차올라서 눈물이납니다..젊은이들이여 꼭 보세요',
#   '10',
#   '158',
#   '29',
#   datetime.datetime(2014, 7, 30, 12, 8),
#   0],
#  ['멋진리쌍(alka****)',
#   '보고 왔습니다... 호불호가 갈리는것 같습니다... 졸던 지지배도 있었습니다... 되도 않되는 소리로 까대는 평론가도 있었습니다... 근데 또 군도는 재밌답니다... 평론가 세대교체가 절실합니다... 전 영화관에서 ...',
#   '10',
#   '161',
#   '32',
#   datetime.datetime(2014, 7, 30, 19, 59),
#   0],
#  ['lmj7****',
#   '역시 최민식의 연기는 혀를 내두르게 합니다. 간민에 좋은 영화 본듯하여 기분 좋네요',
#   '10',
#   '162',
#   '33',
#   datetime.datetime(2014, 7, 30, 10, 27),
#   0],
#  ['메렁ㅋ(smk9****)',
#   '슬프고도 웅장한 전투. 감사합니다.',
#   '9',
#   '150',
#   '32',
#   datetime.datetime(2014, 7, 30, 1, 20),
#   0],
#  ['커피(angt****)',
#   '이순신이라는 성역때문인가 아님 영화사 알바때문인가 ? 평점이?  솔직히  진부하게 신파극을 끼워넣어 산만하고 수준이하의 연출과 편집 안드로메다로 가버린 엉터리고증  명배우와 제작비가 정말 아깝게 느껴진다',
#   '1',
#   '232',
#   '114',
#   datetime.datetime(2014, 8, 1, 23, 5),
#   0],
#  ['도토리묵사발(sinn****)',
#   '꼭봐라 두번봐라 보기전에 이순신 장군 다큐라도 한번 봐라 아니면 보고 나서라도 관련서적이라도 한번봐라 이순신장군 존경하고 또 존경해라',
#   '10',
#   '144',
#   '28',
#   datetime.datetime(2014, 7, 30, 1, 54),
#   0],
#  ['zugp****',
#   '장군님 저희가 꺼내드리겠습니다 이장면 정말 울컥했다 저런지도자면 내목숨을 바처도 아깝지 않을꺼같았다',
#   '10',
#   '137',
#   '23',
#   datetime.datetime(2014, 7, 30, 16, 58),
#   0],
#  ['안녕하세요(john****)',
#   '2시간동안  시간가는줄 몰랐네요. 재미있게 잘보았습니다.',
#   '10',
#   '161',
#   '48',
#   datetime.datetime(2014, 7, 30, 12, 21),
#   '관람객'],
#  ['jsa1****',
#   '그냥 보는 내내 가슴 깊이속에서 말로 표현못한 지금 내 모습에 대한 반성과 선조들에 대한 감사함이 함께했다. 감사합니다. 또 감사합니다. 제가 군입대 전 이걸 봤다면 아마 더욱 열심히 임하지 않았을까 합니다. 감사하...',
#   '10',
#   '139',
#   '33',
#   datetime.datetime(2014, 7, 30, 17, 42),
#   '관람객'],
#  ['jung****',
#   '진심 차라리 위인전을 읽는게 나은 영화입니다.               평점에 속음. 한국인이라면 꼭봐야된다는것도 다 홍보용우는 사람 진심 한명도 없었음 낚이지마세요.                  군도보다 못한 영...',
#   '1',
#   '190',
#   '85',
#   datetime.datetime(2014, 8, 3, 12, 11),
#   0],
#  ['dudt****',
#   '진짜 재미 있던가요?보는내내 지루하고억지 감동을 끌어 낼려는 80년대반공 영화 보는 영화',
#   '1',
#   '218',
#   '113',
#   datetime.datetime(2014, 8, 3, 11, 11),
#   0],
#  ['재호(jhl3****)',
#   '정말 재미없는영화다 군도랑별반다를바가없는영화카메라조작도 부자연스럽고 곳곳에 장면연출과 배우들의 연기력도 너무 부자연스러운 그런 영화. 이영화가 어떻게 흥행되고있다는 기사들이 뜨는지 도저히 모르겠고 언론에 낚인 기분이...',
#   '1',
#   '259',
#   '154',
#   datetime.datetime(2014, 8, 4, 22, 13),
#   '관람객'],
#  ['comj****',
#   '군도보다훨씬 재밌다 최민식 짱',
#   '9',
#   '142',
#   '39',
#   datetime.datetime(2014, 7, 30, 12, 6),
#   0],
#  ['저는(qkrt****)',
#   "진짜 그냥 이순신 장군님이 아님 '이순神 '장군님이십니다.",
#   '10',
#   '115',
#   '13',
#   datetime.datetime(2014, 7, 30, 16, 55),
#   0]]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                      0  ...    6
# 0   chocobar(choc****)  ...    0
# 1       누구세요(h100****)  ...    0
# 2        드리머(hama****)  ...    0
# 3         지영(yjy3****)  ...    0
# 4             csh0****  ...    0
# ..                 ...  ...  ...
# 95            jung****  ...    0
# 96            dudt****  ...    0
# 97        재호(jhl3****)  ...  관람객
# 98            comj****  ...    0
# 99        저는(qkrt****)  ...    0
#
# [100 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#               nickname  ... watch_movie
# 0   chocobar(choc****)  ...           0
# 1       누구세요(h100****)  ...           0
# 2        드리머(hama****)  ...           0
# 3         지영(yjy3****)  ...           0
# 4             csh0****  ...           0
# ..                 ...  ...         ...
# 95            jung****  ...           0
# 96            dudt****  ...           0
# 97        재호(jhl3****)  ...         관람객
# 98            comj****  ...           0
# 99        저는(qkrt****)  ...           0
#
# [100 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
